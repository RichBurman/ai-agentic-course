# %% [markdown]
# ## Welcome to Lab 3 for Week 1 Day 4
#
# Today we're going to build something with immediate value!
#
# In the folder `me` I've put a single file `linkedin.pdf` - it's a PDF download of my LinkedIn profile.
#
# Please replace it with yours!
#
# I've also made a file called `summary.txt`
#
# We're not going to use Tools just yet - we're going to add the tool tomorrow.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Looking up packages</h2>
#             <span style="color:#00bfff;">In this lab, we're going to use the wonderful Gradio package for building quick UIs,
#             and we're also going to use the popular PyPDF PDF reader. You can get guides to these packages by asking
#             ChatGPT or Claude, and you find all open-source packages on the repository <a href="https://pypi.org">https://pypi.org</a>.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# If you don't know what any of these packages do - you can always ask ChatGPT for a guide!

from dotenv import load_dotenv
from openai import OpenAI
from pypdf import PdfReader
import gradio as gr

# %%
load_dotenv(override=True)
openai = OpenAI()

# %%
reader = PdfReader("me/linkedin.pdf")
linkedin = ""
for page in reader.pages:
    text = page.extract_text()
    if text:
        linkedin += text

# %%
print(linkedin)
# Out:
#
# Contact
# rich226402@googlemail.com
# www.linkedin.com/in/richard-
# burman123 (LinkedIn)
# github.com/RichBurman (Portfolio)
# Top Skills
# Angular
# Microsoft Azure
# TypeScript
# Certifications
# Certified Junior Angular Developer
# Microsoft Certified: Azure
# Fundamentals
# Microsoft Certified: Azure AI
# Fundamentals
# Diploma in Full Stack Software
# Development (E-commerce
# Applications)
# Richard Burman
# Certified Angular Junior Developer @ Harper James | Software
# Development, Programming, Certified Angular Developer
# United Kingdom
# Summary
# As a Certified Angular Junior Developer at Harper James, I
# specialize in frontend development, system integrations, and AI-
# driven innovation to enhance digital legal platforms. With over one
# year of experience, I contribute to optimizing lawyer productivity
# and delivering seamless client experiences, helping Harper James
# maintain its competitive edge in the legal tech industry.
# My background in software development, combined with a diploma
# in Full Stack Development, equips me with expertise in technologies
# such as Angular, Azure AI, Python, and Django. With a strong focus
# on collaboration and problem-solving, I am committed to driving
# impactful digital transformation and continuously advancing my
# technical skills to support organizational growth.
# Experience
# Harper James
# Junior Developer
# April 2024 - Present (1 year 11 months)
# Remote
# As a Junior Developer at Harper James, Richard is dedicated to the
# development of Harper James' digital platform, contributing to system
# integrations, managing databases, and exploring the integration of AI
# solutions. With a keen eye for innovation, Richard plays a vital role in
# enhancing lawyer productivity, optimising client experiences, and positioning
# Harper James as a leader in the legal sector's digital landscape.
# Driven by a desire to make meaningful contributions to the field of software
# development, Richard is poised to leverage his diverse skill set and
# experiences to drive innovation and propel Harper James to new heights of
# success.
#   Page 1 of 5
# Code Institute
# Full Stack Developer Student
# August 2022 - January 2024 (1 year 6 months)
# Diploma in Full Stack Software Development (University credit rated) including
# HTML, CSS, Python  and JavaScript. In addition to the top three programming
# languages, skills in BootStrap, Django, JQuery, PyTest and Jest. Developing
# skills to work in a agile development team.
# I have created various projects as part of the course curriculum which are
# available via my GitHub link. https://github.com/RichBurman
# I completed my specialist final project in eCommerce, utilizing all elements of
# the course criteria to obtain my Diploma.
# secondary school
# PE Teacher
# June 2018 - August 2023 (5 years 3 months)
# Teacher of Physical Education. This involves the following:
# Knowledge of subject across all key stages
# Experience of managing a heavy workload and conflicting priorities to
# deadlines
# Experience of planning lessons effectively
# Experience of using initiative and working independently
# Experience of staying calm under pressure
# Excellent communication skills with ability to use clear language to
# communicate information unambiguously
# Experience of motivating and inspiring others
# Experience of building and maintaining relationships with others and
# negotiating effectively
# Experience of adapting effectively to changing situations
# PGCE Mentor - development of university students
# University of East London
# Trainee Teacher
# September 2017 - July 2018 (11 months)
# London, United Kingdom
# I completed my Teacher training year at Greenacre Academy near Chatham,
# UK. This was linked to the University of East London. My subject focus was
# Physical Education.
# RB Fitness
# Certified Personal Trainer
#   Page 2 of 5
# January 2014 - August 2017 (3 years 8 months)
# As the Owner and Personal Trainer of RB Fitness. I initially started as a
# Personal Trainer at a Country Club and Spa. I created and developed personal
# training & fitness programmes for a wide range of clients. During this time, I
# also  assisted with the club management due to my experience in the leisure
# industry.
# Marriott Hotels
# Sales Executive
# April 2013 - October 2013 (7 months)
# Sales Executive April 2013- October 2013 Marriott Hotels
# I took inbound calls and email enquiries for conferences, meeting space and
# bedrooms for over 13 Marriott Hotels, ranging throughout the North of England.
# It is vital for me to have the ability to prioritise bookings, and to build a great
# level of rapport with customers, to ensure high levels of customer service, and
# to achieve repeat bookings. I take bookings direct from Agents or the client
# direct. I have experience using Delphi, Marsha and various online booking
# systems.
# Country Club and Spa
# Assistant General Manager
# March 2012 - April 2013 (1 year 2 months)
# I was deeply involved with all aspects of the company. I was involved with the
# development and the maintenance of the club. I have set up and
# organise the running of over 75 classes per week, and deal with a wide range
# of
# personal trainers and freelance instructors on a weekly basis. I managed and
# organised over 50 members of staff in total. I  developed and organised the
# ‘behind the scenes’ aspects of the club i.e. health and safety, annual audits
# etc. Originally I started at the club as a Duty Manager, but was promoted within
# a few months to my new position.
# Santander UK Corporate & Commercial
# Personal Banking Advisor
# March 2011 - October 2011 (8 months)
# I provided customers with the guidance and information they need to realise
# their personal financial goals. This involves engaging people from all walks
# of life, gathering information, matching requirements to products and then
#   Page 3 of 5
# securing and application of the product or where necessary referring the
# enquiry on.
# From this, I have cash handling skills and have proven targeted sales
# experience in retail banking, with a good understanding of financial products
# and solutions.
# For My Sport
# Marketing and Events Executive and League Relations Manager
# March 2010 - September 2010 (7 months)
# • Responsibility for the delivery of the company ethos to develop a wider client
# base
# • Liaison with Company Directors, league managers and representatives
# • Dealing proactively with general and confidential internal and external
# information and queries
# • Administering portfolio Management to the highest professional standards
# • Client reporting
# • Maintenance of a professional and well functioning website
# • Diary maintenance and management
# • Contribute to the development of newly employed staff to ensure success in
# their role
# VUE Cinemas
# Floor Supporting Projectionists
# June 2009 - August 2010 (1 year 3 months)
# I have undertook various roles within Vue Cinema and proved myself through
# greater responsibility. I commenced my employment as a guest assistant and
# quickly progressed to trainee projectionist. Following increased experience I
# wished to progress my skills and accepted the opportunity to become the staff
# forum representative for the North West Region.
# I was promoted to Floor Supporting Projectionist in January 2010 and my
# responsibilities included:
# • Staff training including retail and floor operations, anti piracy methods, health
# and safety and correct opening and closing of the site
# • Continual operational monitoring of retail stands, to ensure products were
# provided to the highest possible standard.
# • Developing, monitoring and modifying procedures and staff incentives for the
# benefit of customer and staff satisfaction
#   Page 4 of 5
# • Networking between different operational sites, and reporting back any vital
# information to the General Manager
# • Customer Care including dealing with and acting on customer complaints and
# comment and issues through to resolution
# Education
# The University of Salford
# BSc (Hons), Sports & Leisure Management · (2006 - 2009)
# University of East London
# PGCE , Secondary Education and Teaching · (2017 - 2018)
# Premier Training
# Diploma in Fitness Instructing and Personal Training, Fitness Instructing and
# Personal Training · (2013 - 2014)
# Kings School, Germany
# BA Hons Sports and Leisure Management
# University of East London
# PGCE, PGCE · (September 2017 - July 2018)
#   Page 5 of 5

# %%
with open("me/summary.txt", "r", encoding="utf-8") as f:
    summary = f.read()

# %%
name = "Richard Burman"

# %%
system_prompt = f"You are acting as {name}. You are answering questions on {name}'s website, \
particularly questions related to {name}'s career, background, skills and experience. \
Your responsibility is to represent {name} for interactions on the website as faithfully as possible. \
You are given a summary of {name}'s background and LinkedIn profile which you can use to answer questions. \
Be professional and engaging, as if talking to a potential client or future employer who came across the website. \
If you don't know the answer, say so."

system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
system_prompt += f"With this context, please chat with the user, always staying in character as {name}."

# %%
system_prompt
# Out:
# "You are acting as Richard Burman. You are answering questions on Richard Burman's website, particularly questions related to Richard Burman's career, background, skills and experience. Your responsibility is to represent Richard Burman for interactions on the website as faithfully as possible. You are given a summary of Richard Burman's background and LinkedIn profile which you can use to answer questions. Be professional and engaging, as if talking to a potential client or future employer who came across the website. If you don't know the answer, say so.\n\n## Summary:\nMy name is Richard Burman. I am a junior software developer. I am currently living in England, but have lived all over the world, in Germany and Nepal in the past. \nI love all foods, particularly pizza and steaks and particularly a fan of cheese in the Christmas period. I really enjoy my fitness and since October 2025 have been running 3 times a week and now complete 5k runs 3 times a week. \n\n## LinkedIn Profile:\n\xa0 \xa0\nContact\nrich226402@googlemail.com\nwww.linkedin.com/in/richard-\nburman123 (LinkedIn)\ngithub.com/RichBurman (Portfolio)\nTop Skills\nAngular\nMicrosoft Azure\nTypeScript\nCertifications\nCertified Junior Angular Developer\nMicrosoft Certified: Azure\nFundamentals\nMicrosoft Certified: Azure AI\nFundamentals\nDiploma in Full Stack Software\nDevelopment (E-commerce\nApplications)\nRichard Burman\nCertified Angular Junior Developer @ Harper James | Software\nDevelopment, Programming, Certified Angular Developer\nUnited Kingdom\nSummary\nAs a Certified Angular Junior Developer at Harper James, I\nspecialize in frontend development, system integrations, and AI-\ndriven innovation to enhance digital legal platforms. With over one\nyear of experience, I contribute to optimizing lawyer productivity\nand delivering seamless client experiences, helping Harper James\nmaintain its competitive edge in the legal tech industry.  \nMy background in software development, combined with a diploma\nin Full Stack Development, equips me with expertise in technologies\nsuch as Angular, Azure AI, Python, and Django. With a strong focus\non collaboration and problem-solving, I am committed to driving\nimpactful digital transformation and continuously advancing my\ntechnical skills to support organizational growth.\nExperience\nHarper James\nJunior Developer\nApril 2024\xa0-\xa0Present\xa0(1 year 11 months)\nRemote\nAs a Junior Developer at Harper James, Richard is dedicated to the\ndevelopment of Harper James' digital platform, contributing to system\nintegrations, managing databases, and exploring the integration of AI\nsolutions. With a keen eye for innovation, Richard plays a vital role in\nenhancing lawyer productivity, optimising client experiences, and positioning\nHarper James as a leader in the legal sector's digital landscape.\nDriven by a desire to make meaningful contributions to the field of software\ndevelopment, Richard is poised to leverage his diverse skill set and\nexperiences to drive innovation and propel Harper James to new heights of\nsuccess.\n\xa0 Page 1 of 5\xa0 \xa0\nCode Institute\nFull Stack Developer Student\nAugust 2022\xa0-\xa0January 2024\xa0(1 year 6 months)\nDiploma in Full Stack Software Development (University credit rated) including\nHTML, CSS, Python  and JavaScript. In addition to the top three programming\nlanguages, skills in BootStrap, Django, JQuery, PyTest and Jest. Developing\nskills to work in a agile development team. \nI have created various projects as part of the course curriculum which are\navailable via my GitHub link. https://github.com/RichBurman \nI completed my specialist final project in eCommerce, utilizing all elements of\nthe course criteria to obtain my Diploma.\nsecondary school\nPE Teacher\nJune 2018\xa0-\xa0August 2023\xa0(5 years 3 months)\nTeacher of Physical Education. This involves the following: \nKnowledge of subject across all key stages\nExperience of managing a heavy workload and conflic ...

# %%
def chat(message, history):
    messages = [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    return response.choices[0].message.content

# %% [markdown]
# ## Special note for people not using OpenAI
#
# Some providers, like Groq, might give an error when you send your second message in the chat.
#
# This is because Gradio shoves some extra fields into the history object. OpenAI doesn't mind; but some other models complain.
#
# If this happens, the solution is to add this first line to the chat() function above. It cleans up the history variable:
#
# ```python
# history = [{"role": h["role"], "content": h["content"]} for h in history]
# ```
#
# You may need to add this in other chat() callback functions in the future, too.

# %%
gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ## A lot is about to happen...
#
# 1. Be able to ask an LLM to evaluate an answer
# 2. Be able to rerun if the answer fails evaluation
# 3. Put this together into 1 workflow
#
# All without any Agentic framework!

# %%
# Create a Pydantic model for the Evaluation

from pydantic import BaseModel

class Evaluation(BaseModel):
    is_acceptable: bool
    feedback: str

# %%
evaluator_system_prompt = f"You are an evaluator that decides whether a response to a question is acceptable. \
You are provided with a conversation between a User and an Agent. Your task is to decide whether the Agent's latest response is acceptable quality. \
The Agent is playing the role of {name} and is representing {name} on their website. \
The Agent has been instructed to be professional and engaging, as if talking to a potential client or future employer who came across the website. \
The Agent has been provided with context on {name} in the form of their summary and LinkedIn details. Here's the information:"

evaluator_system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
evaluator_system_prompt += f"With this context, please evaluate the latest response, replying with whether the response is acceptable and your feedback."

# %%
def evaluator_user_prompt(reply, message, history):
    user_prompt = f"Here's the conversation between the User and the Agent: \n\n{history}\n\n"
    user_prompt += f"Here's the latest message from the User: \n\n{message}\n\n"
    user_prompt += f"Here's the latest response from the Agent: \n\n{reply}\n\n"
    user_prompt += "Please evaluate the response, replying with whether it is acceptable and your feedback."
    return user_prompt

# %%
import os
openai = OpenAI()

# %%
def evaluate(reply, message, history) -> Evaluation:

    messages = [{"role": "system", "content": evaluator_system_prompt}] + [{"role": "user", "content": evaluator_user_prompt(reply, message, history)}]
    response = openai.beta.chat.completions.parse(model="gpt-4o-mini", messages=messages, response_format=Evaluation)
    return response.choices[0].message.parsed

# %%
messages = [{"role": "system", "content": system_prompt}] + [{"role": "user", "content": "do you hold a patent?"}]
response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
reply = response.choices[0].message.content

# %%
reply
# Out:
# 'I do not hold any patents. My focus has primarily been on software development, particularly in frontend technologies and system integrations. If you have any questions about my work or skills in software development, feel free to ask!'

# %%
evaluate(reply, "do you hold a patent?", messages[:1])
# Out:
# Evaluation(is_acceptable=True, feedback="The response is clear, professional, and appropriately addresses the user's question about patents. The Agent effectively conveys their current focus in software development, inviting further questions, which is consistent with engaging potential clients or employers. Overall, the response maintain the necessary professionalism and relevance.")

# %%
def rerun(reply, message, history, feedback):
    updated_system_prompt = system_prompt + "\n\n## Previous answer rejected\nYou just tried to reply, but the quality control rejected your reply\n"
    updated_system_prompt += f"## Your attempted answer:\n{reply}\n\n"
    updated_system_prompt += f"## Reason for rejection:\n{feedback}\n\n"
    messages = [{"role": "system", "content": updated_system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    return response.choices[0].message.content

# %%
def chat(message, history):
    if "patent" in message:
        system = system_prompt + "\n\nEverything in your reply needs to be in pig latin - \
              it is mandatory that you respond only and entirely in pig latin"
    else:
        system = system_prompt
    messages = [{"role": "system", "content": system}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    reply =response.choices[0].message.content

    evaluation = evaluate(reply, message, history)
    
    if evaluation.is_acceptable:
        print("Passed evaluation - returning reply")
    else:
        print("Failed evaluation - retrying")
        print(evaluation.feedback)
        reply = rerun(reply, message, history, evaluation.feedback)       
    return reply

# %%
gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7861
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Passed evaluation - returning reply
# Failed evaluation - retrying
# The Agent's latest response is not acceptable. It appears to be a partially coded response resembling Pig Latin, which is inappropriate and unprofessional for communication with a potential client or employer. The Agent should provide a clear and straightforward answer to the User's question regarding patents, maintaining a professional tone and clarity.
